# %%
import os

from os.path import join, getsize

for root, dirs, files in os.walk('/Users/manuelfernandezlemos/Desktop/pythonsupport-page/pythonsupport-page'):
    print(files)
# Out:
# ['.DS_Store', 'LICENSE', 'requirements.txt', 'Dockerfile', 'Makefile', 'README.md', 'make.bat', '.gitignore']
# []
# ['LICENSE', 'requirements.txt', 'README.md', 'main.py']
# ['index.rst', 'conf.py', 'spelling_wordlist.txt', 'README.md', 'ps_configuration.toml']
# ['deletePythonMac.sh', 'Remove260CharacterPathLimit.reg']
# ['create_timetabs.py', 'pageredirects.py', '__init__.py']
# ['create_timetabs.cpython-311.pyc', 'pageredirects.cpython-311.pyc', '__init__.cpython-311.pyc']
# ['index.rst', 'environment-venv.rst.include', 'install-verify.rst', 'poetry.rst', 'environment-conda.rst.include', 'install-conda.rst', 'supported.rst', 'pyenv.rst', 'uninstall-vscode.rst', 'uninstall-conda.rst', 'uninstall.rst', 'pip.rst', 'uninstall-python.rst', 'environments.rst', 'conda.rst', 'pipenv.rst', 'install-python.rst', 'environment-virtualenv.rst.include']
# ...
